# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import random
import pandas as pd
pynt=True
if pynt:
    import pynt
    pynt.set_style('pynt')
    pynt.set_fontsize(12)

# Global variables
operations=np.array(["NOT", "NAND", "AND", "ORN", "OR", "ANDN", "NOR", "XOR", "EQU"])
Phi_0=np.array([1,1,2,2,3,3,4,4,5])

# %%
def read_update_data(M, N, chromosome_length=9):
    data = np.genfromtxt(f"./cbuild/work/data/AGIdata/run/meta/M{M}/N{N}.csv", delimiter=',', skip_header=1)
    update=data[:,0]
    gen=data[:,1]
    phi_i=data[:,2]
    phi_0=data[:,3]
    n_orgs=data[:,4]
    tasks = np.array([data[:,i] for i in range(5,5+chromosome_length)])
    update_data = {"updates": update, "generation": gen, "phi_i":phi_i, "phi_0":phi_0, "n_orgs": n_orgs, "tasks": tasks}
    return update_data

# %%
def plot_update_data(M, N, ax, flag=0, prints=True):
    data = read_update_data(M, N)
    if flag==0:
        #plot phi_0
        ax.plot(data["updates"], data["phi_0"], label=fr"($m,n$)=({M},{N})")
        ax.set(xlabel="updates", ylabel="Fitness", yscale='log')
        ax.legend()
        temp = data['phi_0']
        print(f"(m,n)=({M},{N}): Sum of phi_0: {np.sum(temp): .2g}, Phi_0 at last update {temp[-1]} " )
    elif flag==1:
        #plot tasks
        for j in range(len(data["tasks"])):
            ax.plot(data["updates"], data["tasks"][j]/data["n_orgs"], label=f"{operations[j]}")
        ax.legend(ncol=2)
        ax.set(xlabel="updates", ylabel="Fraction of population", ylim=[0,1])
        temp=data["tasks"]
        print(f"(m,n)=({M},{N}): Sum of tasks: {np.sum(np.sum(temp,axis=1)): .2g},\n {np.sum(temp,axis=1):}")
    elif flag==2:
        #plot phi_0 sum
        phi_0_cum_sum = [0]
        for i, phi_0_u in enumerate(data["phi_0"]):
            phi_0_cum_sum.append(phi_0_cum_sum[-1] + phi_0_u)
        ax.plot(data["updates"], phi_0_cum_sum[1:], label=fr"($m,n$)=({M},{N})")
        ax.set(xlabel="updates", ylabel=r"Cumulative sum of $\Phi_0$", yscale="log")
        ax.legend()

# %%
def read_meta_data(chromosome_length):
    data = np.genfromtxt(f"./cbuild/work/data/AGIdata/run/metarun.csv", delimiter=',', skip_header=1)
    m=data[:,0]
    phi_0_max=data[:,1]
    hat_phi = np.array([data[:,i] for i in range(2,2+chromosome_length)])
    meta_data = {"m":m, "phi_0_max":phi_0_max, "chromosome":hat_phi }
    return meta_data

# %%
def plot_meta_data(ax, flag=0, task=0):
    data = read_meta_data(9)
    if flag==0:
        ax.plot(data['m'], data['phi_0_max'])
        ax.set(xlabel='Meta Generation', ylabel=r"Max fitness $\Phi_0$", yscale='log')
    if flag==1:
        ax.plot(data['m'], data['chromosome'][task])
        ax.set(ylabel="chromosome", title=f"Task {task}", xlabel=r'$m$')

# %%
fig = plt.figure(constrained_layout=True)
gs = GridSpec(4, 3, figure=fig)
ax1 = fig.add_subplot(gs[0, :])
# identical to ax1 = plt.subplot(gs.new_subplotspec((0, 0), colspan=3))
ax=[]
for i in range(1,4):
    for j in range(3):
        ax.append(fig.add_subplot(gs[i, j]))

# %%
def read_settings_data():
    df = pd.read_csv(f"./cbuild/work/data/AGIdata/run/settings.csv")
    return df

# %%
df = pd.read_csv(f"./cbuild/work/data/AGIdata/run/settings.csv")
df[' gene_max'][0]
# Out:
# 25.0

# %%
def produce_meta_report():
    print("***** REPORT *****")
    print("Settings:")
    df = read_settings_data()
    gene_min=df[' gene_min'][0]; gene_max=df[' gene_max'][0]
    print("Best fintess per meta generation and the corresponding chromosomes")
    fig = plt.figure(constrained_layout=True, figsize=(16,12))
    gs = GridSpec(4, 3, figure=fig)
    axs = [fig.add_subplot(gs[0, :])]
    for i in range(1,4):
        for j in range(3):
            axs.append(fig.add_subplot(gs[i, j]))
            
            
    plot_meta_data(axs[0], flag=0)
    for task, ax in enumerate(axs[1:]):
        plot_meta_data(ax, flag=1, task=task)
        ax.set(ylim=[gene_min, gene_max])

# %%
produce_meta_report()
# Out:
# ***** REPORT *****
# Settings:
# Best fintess per meta generation and the corresponding chromosomes

# %%
fig, axs = plt.subplots(5,1, figsize=(20,14))
plot_update_data(0,0, axs[0], flag=0)
plot_update_data(10,0, axs[0], flag=0)
plot_update_data(20,0, axs[0], flag=0)
plot_update_data(0,0, axs[1], flag=2)
plot_update_data(10,0, axs[1], flag=2)
plot_update_data(20,0, axs[1], flag=2)
plot_update_data(0,0, axs[2], flag=1)
plot_update_data(10,0, axs[3], flag=1)
plot_update_data(20,0, axs[4], flag=1)
# Out:
# (m,n)=(0,0): Sum of phi_0:  1.5e+03, Phi_0 at last update 30.598177
# (m,n)=(10,0): Sum of phi_0:  2.9e+06, Phi_0 at last update 21178.759442
# (m,n)=(20,0): Sum of phi_0:  4.2e+06, Phi_0 at last update 168011.165631
# (m,n)=(0,0): Sum of tasks:  1.4e+06,
#  [1.054549e+06 9.488500e+04 3.051900e+04 1.057990e+05 2.340000e+02
#  8.560200e+04 1.700900e+04 5.900000e+01 0.000000e+00]
# (m,n)=(10,0): Sum of tasks:  2.1e+06,
#  [546919. 169431. 137026. 321185. 262620. 144572. 409683.      0. 128454.]
# (m,n)=(20,0): Sum of tasks:  1.4e+06,
#  [978128. 168413.   5885.  66054.  40751.  86432.  37809.   7250.  11651.]
